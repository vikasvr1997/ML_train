# %% [markdown]
# <a href="https://colab.research.google.com/github/vikasvr1997/ML_train/blob/main/Random_forests_and_Decision_Trees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('kyphosis.csv')

# %%
df.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
sns.pairplot(df, hue = 'Kyphosis', diag_kind= 'hist')

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Kyphosis', axis = 1)
y = df['Kyphosis']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size= 0.3)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
print(classification_report(y_test, predictions))
print(confusion_matrix(y_test,predictions))
accuracy_score(y_test,predictions)
# Out:
#               precision    recall  f1-score   support
#
#       absent       0.90      0.90      0.90        21
#      present       0.50      0.50      0.50         4
#
#     accuracy                           0.84        25
#    macro avg       0.70      0.70      0.70        25
# weighted avg       0.84      0.84      0.84        25
#
# [[19  2]
#  [ 2  2]]
# 0.84

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
Ran_model = RandomForestClassifier(n_estimators= 200)

# %%
Ran_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
pred = Ran_model.predict(X_test)

# %%
print(classification_report(y_test, pred))
print(confusion_matrix(y_test,pred))
accuracy_score(y_test,pred)
# Out:
#               precision    recall  f1-score   support
#
#       absent       0.89      0.81      0.85        21
#      present       0.33      0.50      0.40         4
#
#     accuracy                           0.76        25
#    macro avg       0.61      0.65      0.62        25
# weighted avg       0.80      0.76      0.78        25
#
# [[17  4]
#  [ 2  2]]
# 0.76
